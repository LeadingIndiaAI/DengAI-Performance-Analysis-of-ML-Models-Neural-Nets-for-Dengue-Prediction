# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("dengue_features_train.csv")

# %%
df
# Out:
#      city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0      sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1      sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2      sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3      sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4      sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
# 5      sj  1990          23      1990-06-04       NaN  0.174850  0.254314
# 6      sj  1990          24      1990-06-11  0.112900  0.092800  0.205071
# 7      sj  1990          25      1990-06-18  0.072500  0.072500  0.151471
# 8      sj  1990          26      1990-06-25  0.102450  0.146175  0.125571
# 9      sj  1990          27      1990-07-02       NaN  0.121550  0.160683
# 10     sj  1990          28      1990-07-09  0.192875  0.082350  0.191943
# 11     sj  1990          29      1990-07-16  0.291600  0.211800  0.301200
# ...

# %%
df.shape
# Out:
# (1456, 24)

# %%
datadict = pd.DataFrame(df.dtypes)

# %%
datadict['Missing Values'] = df.isnull().sum()

# %%
datadict["Nunique"] = df.nunique()

# %%
datadict["Count"] = df.count()

# %%
datadict
# Out:
#                                              0  Missing Values  Nunique  Count
# city                                    object               0        2   1456
# year                                     int64               0       21   1456
# weekofyear                               int64               0       53   1456
# week_start_date                         object               0     1049   1456
# ndvi_ne                                float64             194     1214   1262
# ndvi_nw                                float64              52     1365   1404
# ndvi_se                                float64              22     1395   1434
# ndvi_sw                                float64              22     1388   1434
# precipitation_amt_mm                   float64              13     1157   1443
# reanalysis_air_temp_k                  float64              10     1176   1446
# reanalysis_avg_temp_k                  float64              10      600   1446
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
del df['week_start_date']

# %%
df
# Out:
#      city  year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0      sj  1990          18  0.122600  0.103725  0.198483  0.177617
# 1      sj  1990          19  0.169900  0.142175  0.162357  0.155486
# 2      sj  1990          20  0.032250  0.172967  0.157200  0.170843
# 3      sj  1990          21  0.128633  0.245067  0.227557  0.235886
# 4      sj  1990          22  0.196200  0.262200  0.251200  0.247340
# 5      sj  1990          23       NaN  0.174850  0.254314  0.181743
# 6      sj  1990          24  0.112900  0.092800  0.205071  0.210271
# 7      sj  1990          25  0.072500  0.072500  0.151471  0.133029
# 8      sj  1990          26  0.102450  0.146175  0.125571  0.123600
# 9      sj  1990          27       NaN  0.121550  0.160683  0.202567
# 10     sj  1990          28  0.192875  0.082350  0.191943  0.152929
# 11     sj  1990          29  0.291600  0.211800  0.301200  0.280667
# 12     sj  1990          30  0.150567  0.171700  0.226900  0.214557
# ...

# %%
X_train = df.iloc[:, :].values

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
from sklearn.preprocessing import Imputer

# %%
imputer = Imputer()

# %%
X_train[:,3:23] = imputer.fit_transform(X_train[:, 3:23])

# %%
X_train
# Out:
# array([['sj', 1990, 18, ..., 29.4, 20.0, 16.0],
#        ['sj', 1990, 19, ..., 31.7, 22.2, 8.6],
#        ['sj', 1990, 20, ..., 32.2, 22.8, 41.4],
#        ...,
#        ['iq', 2010, 23, ..., 32.2, 19.2, 7.4],
#        ['iq', 2010, 24, ..., 31.2, 21.0, 16.0],
#        ['iq', 2010, 25, ..., 33.7, 22.2, 20.4]], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder?

# %%
encoder = LabelEncoder()

# %%
X_train[:,0] = encoder.fit_transform(X_train[:,0])

# %%
X_train
# Out:
# array([[1, 1990, 18, ..., 29.4, 20.0, 16.0],
#        [1, 1990, 19, ..., 31.7, 22.2, 8.6],
#        [1, 1990, 20, ..., 32.2, 22.8, 41.4],
#        ...,
#        [0, 2010, 23, ..., 32.2, 19.2, 7.4],
#        [0, 2010, 24, ..., 31.2, 21.0, 16.0],
#        [0, 2010, 25, ..., 33.7, 22.2, 20.4]], dtype=object)

# %%
X_train
# Out:
# array([[1, 1990, 18, ..., 29.4, 20.0, 16.0],
#        [1, 1990, 19, ..., 31.7, 22.2, 8.6],
#        [1, 1990, 20, ..., 32.2, 22.8, 41.4],
#        ...,
#        [0, 2010, 23, ..., 32.2, 19.2, 7.4],
#        [0, 2010, 24, ..., 31.2, 21.0, 16.0],
#        [0, 2010, 25, ..., 33.7, 22.2, 20.4]], dtype=object)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
# Out:
# /anaconda3/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
X_train
# Out:
# array([[ 0.74535599, -2.04044804, -0.56635649, ..., -1.56926583,
#         -1.34242291, -0.49547268],
#        [ 0.74535599, -2.04044804, -0.49975322, ..., -0.38682995,
#          0.06248668, -0.65265527],
#        [ 0.74535599, -2.04044804, -0.43314995, ..., -0.12977867,
#          0.44564384,  0.04404597],
#        ...,
#        [-1.34164079,  1.65883268, -0.23334015, ..., -0.12977867,
#         -1.85329913, -0.67814434],
#        [-1.34164079,  1.65883268, -0.16673689, ..., -0.64388123,
#         -0.70382764, -0.49547268],
#        [-1.34164079,  1.65883268, -0.10013362, ...,  0.64137516,
#          0.06248668, -0.40201275]])

# %%
df2 = pd.read_csv("dengue_labels_train.csv")

# %%
df2
# Out:
#      city  year  weekofyear  total_cases
# 0      sj  1990          18            4
# 1      sj  1990          19            5
# 2      sj  1990          20            4
# 3      sj  1990          21            3
# 4      sj  1990          22            6
# 5      sj  1990          23            2
# 6      sj  1990          24            4
# 7      sj  1990          25            5
# 8      sj  1990          26           10
# 9      sj  1990          27            6
# 10     sj  1990          28            8
# 11     sj  1990          29            2
# 12     sj  1990          30            6
# 13     sj  1990          31           17
# 14     sj  1990          32           23
# 15     sj  1990          33           13
# 16     sj  1990          34           21
# 17     sj  1990          35           28
# 18     sj  1990          36           24
# 19     sj  1990          37           20
# 20     sj  1990          38           40
# 21     sj  1990          39           27
# ...

# %%
y_train = df2.iloc[:,3].values

# %%
y_train
# Out:
# array([4, 5, 4, ..., 1, 1, 4])

# %%
np.savetxt("preprocessed_X_train.csv", X_train, delimiter=",")

# %%
np.savetxt("preprocessed_y_train.csv", y_train, delimiter=",")

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
X_train[1426]
# Out:
# array([-1.34164079,  1.47386864,  1.49834479,  1.57693226,  1.35699935,
#         2.82270627,  2.02014619,  0.63647172,  0.04494687,  0.56497228,
#         1.13246534,  1.69841127, -0.28139802,  2.178834  ,  1.33953278,
#         0.63647172,  1.25272109,  0.80763374,  0.65941394,  1.1047218 ,
#         1.46393924,  0.06248668,  0.20547674])

# %%
y_train[1426]
# Out:
# 4

# %%
regressor.predict(X_train[1426:1427])
# Out:
# array([22.56691396])

# %%
y_train[718]
# Out:
# 9

# %%
regressor.predict(X_train[718:719])
# Out:
# array([6.93781626])

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()

# %%
X_train = pca.fit_transform(X_train)

# %%
X_test = pca.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-c755556f7e1e> in <module>()
# ----> 1 X_test = pca.transform(X_test)
#
# NameError: name 'X_test' is not defined

# %%
df4 = pd.read_csv("dengue_features_test.csv")

# %%
df4
# Out:
#     city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0     sj  2008          18      2008-04-29 -0.018900 -0.018900  0.102729
# 1     sj  2008          19      2008-05-06 -0.018000 -0.012400  0.082043
# 2     sj  2008          20      2008-05-13 -0.001500       NaN  0.151083
# 3     sj  2008          21      2008-05-20       NaN -0.019867  0.124329
# 4     sj  2008          22      2008-05-27  0.056800  0.039833  0.062267
# 5     sj  2008          23      2008-06-03 -0.044000 -0.030467  0.132000
# 6     sj  2008          24      2008-06-10 -0.044300 -0.024925  0.132271
# 7     sj  2008          25      2008-06-17       NaN  0.082150  0.144371
# 8     sj  2008          26      2008-06-24  0.010800  0.049900  0.100571
# 9     sj  2008          27      2008-07-01  0.072667  0.106660  0.155429
# 10    sj  2008          28      2008-07-08 -0.046450  0.006825  0.260286
# 11    sj  2008          29      2008-07-15       NaN       NaN  0.195843
# ...

# %%
del df4["week_start_date"]

# %%
X_test = df4.iloc[:,:].values

# %%
X_test[:,3:23] = imputer.fit_transform(X_test[:, 3:23])

# %%
X_test
# Out:
# array([['sj', 2008, 18, ..., 33.3, 21.7, 75.2],
#        ['sj', 2008, 19, ..., 30.0, 22.2, 34.3],
#        ['sj', 2008, 20, ..., 32.8, 22.8, 3.0],
#        ...,
#        ['iq', 2013, 24, ..., 32.6, 21.6, 93.2],
#        ['iq', 2013, 25, ..., 32.2, 21.8, 34.1],
#        ['iq', 2013, 26, ..., 32.6, 22.0, 14.9]], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
X_test[:,0] = encoder.fit_transform(X_test[:, 0])

# %%
X_test
# Out:
# array([[1, 2008, 18, ..., 33.3, 21.7, 75.2],
#        [1, 2008, 19, ..., 30.0, 22.2, 34.3],
#        [1, 2008, 20, ..., 32.8, 22.8, 3.0],
#        ...,
#        [0, 2013, 24, ..., 32.6, 21.6, 93.2],
#        [0, 2013, 25, ..., 32.2, 21.8, 34.1],
#        [0, 2013, 26, ..., 32.6, 22.0, 14.9]], dtype=object)

# %%
X_train = sc.inverse_transform(X_train)

# %%
X_train
# Out:
# array([[-7.73228906e-01,  2.02001370e+03,  2.60899092e+01, ...,
#          3.25992905e+01,  2.21211241e+01,  3.93263598e+01],
#        [-4.95553647e-01,  2.00769261e+03,  2.26317693e+01, ...,
#          3.24686196e+01,  2.20783686e+01,  3.93263598e+01],
#        [-3.63778625e-01,  1.99964209e+03,  3.31506235e+01, ...,
#          3.24286897e+01,  2.21327595e+01,  3.93263598e+01],
#        ...,
#        [ 1.71799150e+00,  2.01595098e+03,  5.10313193e+01, ...,
#          3.23541714e+01,  2.21140043e+01,  3.93263598e+01],
#        [ 2.23486243e+00,  2.01516688e+03,  4.48239009e+01, ...,
#          3.23447213e+01,  2.21126197e+01,  3.93263598e+01],
#        [ 2.54928665e+00,  2.00275840e+03,  1.56056806e+01, ...,
#          3.24099101e+01,  2.21112187e+01,  3.93263598e+01]])

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()

# %%
X_train = pca.fit_transform(X_train)

# %%
X_test = pca.transform(X_test)

# %%
pca.explained_variance_ratio_
# Out:
# array([4.88877418e-01, 2.54885655e-01, 1.20959977e-01, 6.68869755e-02,
#        6.28801404e-02, 2.14864471e-03, 9.50870198e-04, 7.65591724e-04,
#        5.28145002e-04, 3.62548415e-04, 2.60824922e-04, 2.53157699e-04,
#        1.52007430e-04, 3.86487982e-05, 1.41525358e-05, 1.19685068e-05,
#        9.17637796e-06, 6.27451503e-06, 2.90860877e-06, 2.16167676e-06,
#        2.01936950e-06, 7.33569467e-07, 4.57354562e-28])
